# %%
# !pip uninstall tensorflow

# %%
# !pip install tensorflow==2.12.0

# %%
# !unzip 'audios.zip' -d audios/

# %% [markdown]
# ## Ejemplo de visualización de audio

# %%
from tensorflow.python.ops.logging_ops import audio_summary
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def plot_audio(filepath):

  #Cargar el archivo binario
  audio_binary=tf.io.read_file(filepath)

  # Decodificar el contenido del archivo binario
  # Secuencia de escalares (magnitudes) y frecuencia de muestreo
  audio, audioSR = tf.audio.decode_wav(audio_binary)
  #print(audio.shape)

  # Trabajaremos con un eje
  audio = tf.squeeze(audio, axis=-1)

  t = np.arange(0, len(audio))
  plt.plot(t, audio, 'g')
  plt.show()

# %%
filepath='/content/audios/on/on_0.wav'
plot_audio(filepath)

# %% [markdown]
# ## Reproducción de audio

# %%
from IPython.display import Audio, display

def play_audio(filepath):

  #Cargar el archivo binario
  audio_binary=tf.io.read_file(filepath)

  # Decodificar el contenido del archivo binario
  # Secuencia de escalares (magnitudes) y frecuencia de muestreo
  audio, audioSR = tf.audio.decode_wav(audio_binary)

  audio = tf.squeeze(audio, axis=-1)
  sr = tf.get_static_value(audioSR)
  display(Audio(audio, rate=audioSR, autoplay=False))

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
play_audio('/content/audios/on/on_0.wav')

# %% [markdown]
# ## Uso de STFT para obtener los espectros de frecuencia y magnitudes

# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)

def audioToTensor(filepath):
  #Cargar el archivo binario
  audio_binary=tf.io.read_file(filepath)

  # Decodificar el contenido del archivo binario
  # Secuencia de escalares (magnitudes) y frecuencia de muestreo
  audio, audioSR = tf.audio.decode_wav(audio_binary)

  audio = tf.squeeze(audio, axis=-1)
  sr = tf.get_static_value(audioSR)

  spectro = tf.signal.stft(audio, frame_length=512, frame_step=128)
  spectro = tf.abs(spectro)
  return spectro
# Out:
# 2026-04-05 08:39:32.957383: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2026-04-05 08:39:32.957406: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2.9.1

# %%
s = audioToTensor('/content/audios/off/off_0.wav')
print(s.shape)

# %% [markdown]
# ## Visualizar el espectrograma

# %%
def plot_spectrogram(spectrogram):
  h = spectrogram.shape[0]
  w = spectrogram.shape[1]
  spec_log = np.log(tf.transpose(spectrogram) + np.finfo(float).eps)
  plt.xlabel("Tiempo")
  plt.ylabel("Frecuencia")
  plt.pcolormesh(range(h), range(w), spec_log)
  plt.show()

# %%
plot_spectrogram(s)

# %% [markdown]
# ## Crear generador de datos

# %%
# Crear las listas archivos de audio y su etiqueta correspondiente

from tensorflow.keras.utils import to_categorical
import glob
import os

def getExamples(datafolder):
  X_audio = []
  Y_command = []

  # Comandos
  commands = [os.path.basename(x) for x in glob.glob(datafolder + '*')]
  print(commands)

  for i, command in enumerate(commands):
    for file in glob.glob(os.path.join(datafolder, command) + '/*.wav'):
      X_audio.append(file)
      Y_command.append(np.array(to_categorical(i, num_classes=len(commands))))
  return np.asarray(X_audio), np.asarray(Y_command)

# %%
datafolder= '/content/audios/'
X_audio, Y_command = getExamples(datafolder)

# %%
print(len(X_audio), len(Y_command))

# %%
from sklearn.model_selection import train_test_split

X_audio, X_audio_test, Y_command, Y_command_test = train_test_split(X_audio, Y_command, test_size=0.25)
print(len(X_audio))
print(len(Y_command))

# %%
# Implementar el generador de Datos

class MySequence(tf.keras.utils.Sequence):

  def __init__(self, x_audio, y_command, batch_size):
    self.x_audio = x_audio
    self.y_command = y_command
    self.batch_size = batch_size

  def __len__(self):
    return len(self.x_audio)//self.batch_size

  def __getitem__(self, idx):

    batch_y = self.y_command[idx * self.batch_size : (idx+1)*self.batch_size]
    batch_x = np.zeros((self.batch_size, s.shape[0], s.shape[1]))
    for i in range(0, self.batch_size):
      batch_x[i] = audioToTensor(self.x_audio[idx * self.batch_size + i])
    return batch_x, batch_y

# %%
# Verificar la forma de los datos de entrada y la salida esperada

mS=MySequence(X_audio, Y_command, 16)
i=iter(mS)
bx, by = next(i)
print(bx.shape, by.shape)

# %%
# Ejemplo de modelo basado en redes neuronales recurrentes

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, Reshape
from tensorflow.keras.layers import MaxPooling2D, Dropout, Flatten, Resizing

input_tensor = Input(shape=(247, 257))
x = Reshape((247, 257, 1))(input_tensor)
x = Resizing(32,32)(x)
x = BatchNormalization()(x)
#x = Reshape((x.shape[1], x.shape[2], 1))(x)
x = Conv2D(32, 3, activation='relu')(x)
x = Conv2D(64, 3, activation='relu')(x)
x = MaxPooling2D()(x)
x = Dropout(0.25)(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
output_tensor = Dense(4, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=output_tensor)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
# Out:
# 2026-04-05 08:39:51.594689: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2026-04-05 08:39:51.594727: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2026-04-05 08:39:51.594753: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lozano-Precision-7520): /proc/driver/nvidia/version does not exist
# 2026-04-05 08:39:51.595009: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 247, 257)]        0
#
#  reshape (Reshape)           (None, 247, 257, 1)       0
#
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  batch_normalization (BatchN  (None, 32, 32, 1)        4
#  ormalization)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 64)                802880
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 821,960
# Trainable params: 821,958
# Non-trainable params: 2
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file="model.png", show_shapes=True)

# %%
batch_size = 1
epochs = 5
h = model.fit(MySequence(X_audio, Y_command, batch_size),
              shuffle=True,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=MySequence(X_audio_test, Y_command_test, batch_size))

# %% [markdown]
# ## Reconocimiento de comandos

# %%
tensor = audioToTensor('/content/audios/on/on_0.wav')
tensor=tf.reshape(tensor, (1,247, 257,1))
print(tensor.shape)

# %%
datafolder='/content/audios/'
commands = [os.path.basename(x) for x in glob.glob(datafolder + '*')]

#Predicción
r = model.predict(tensor)
print(r[0])
print(commands[r[0].argmax()])

# %% [markdown]
# ## Guardar, cargar y verificar el modelo

# %%
model.save('modelAudioRecognition.h5')

# %%
from keras.models import load_model
smodel=load_model('modelAudioRecognition.h5')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(smodel)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open('audio_cnn.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpaoh1uk8_/assets
# INFO:tensorflow:Assets written to: /tmp/tmpaoh1uk8_/assets
# 2026-04-05 08:40:24.774982: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2026-04-05 08:40:24.775057: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2026-04-05 08:40:24.775831: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /tmp/tmpaoh1uk8_
# 2026-04-05 08:40:24.777924: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2026-04-05 08:40:24.777949: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /tmp/tmpaoh1uk8_
# 2026-04-05 08:40:24.783891: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2026-04-05 08:40:24.785462: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2026-04-05 08:40:24.832018: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /tmp/tmpaoh1uk8_
# 2026-04-05 08:40:24.854655: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 78825 microseconds.
# 2026-04-05 08:40:24.883583: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:263] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
